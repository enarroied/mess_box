# %%
import pandas as pd
from great_tables import GT, loc, style

# %% [markdown]
# # Creating a table display from Paris 2024 Olympic Medals.
#
# ## Preparing the data
#
# Before creating the display table, we process the DataFrame.  We get Paris 2024 data, and we get the total, gold, silver and bronze medals by Committee and discipline.

# %%
df_olympic = pd.read_csv("./input/olympic_medals.csv")
df_paris_2024 = df_olympic[df_olympic.Olympiad == "Paris 2024"]
df_paris_2024.head(2)
# Out:
#          Olympiad Discipline          Event          Winner Medal_type  \
# 20433  Paris 2024  Athletics   Women's 800m    Tsige Duguma     Silver
# 20434  Paris 2024  Athletics  Men's 10,000m  Berihu Aregawi     Silver
#
#       Olympic_city  Olympic_year Olympic_season Gender Code Committee  \
# 20433        Paris          2024         summer  Women  ETH  Ethiopia
# 20434        Paris          2024         summer    Men  ETH  Ethiopia
#
#       Committee_type
# 20433        Country
# 20434        Country

# %%
medal_counts = (
    df_paris_2024.groupby(["Committee", "Code", "Medal_type"])
    .size()
    .unstack(fill_value=0)  # Turn Medal_type into columns
    .reset_index()
)

medal_counts["Total"] = medal_counts[["Gold", "Silver", "Bronze"]].sum(axis=1)
medal_counts.sample(3)
# Out:
# Medal_type          Committee Code  Bronze  Gold  Silver  Total
# 10                     Brazil  BRA      20     6      14     40
# 61                   Mongolia  MGL       0     0       2      2
# 83          South South Korea  KOR      10    13       9     32

# %%
# Sort by Discipline, then by Gold → Silver → Bronze (descending)
medal_counts = medal_counts.sort_values(
    by=["Gold", "Silver", "Bronze"], ascending=[False, False, False]
)
medal_counts.head(3)
# Out:
# Medal_type      Committee Code  Bronze  Gold  Silver  Total
# 93          United States  USA      84    80      88    252
# 15                  China  CHN      48    80      54    182
# 51                  Japan  JPN      26    40      24     90

# %%
# Group also by Gender to get medal counts per gender
gender_counts = (
    df_paris_2024[df_paris_2024["Medal_type"].isin(["Gold", "Silver", "Bronze"])]
    .groupby(["Committee", "Gender", "Medal_type"])
    .size()
    .unstack("Medal_type", fill_value=0)
    .reindex(columns=["Gold", "Silver", "Bronze"], fill_value=0)
)

# %%
gender_flat = gender_counts.stack(level=0).unstack(  # Stack Gender
    "Gender"
)  # Gender to columns

# %%
gender_flat
# Out:
# Gender                 Men  Mixed  Open  Openpen  Women
# Committee  Medal_type
# Albania    Gold        0.0    NaN   NaN      NaN    NaN
#            Silver      0.0    NaN   NaN      NaN    NaN
#            Bronze      4.0    NaN   NaN      NaN    NaN
# Algeria    Gold        0.0    NaN   NaN      NaN    4.0
#            Silver      0.0    NaN   NaN      NaN    0.0
# ...                    ...    ...   ...      ...    ...
# Uzbekistan Silver      2.0    NaN   NaN      NaN    2.0
#            Bronze      6.0    NaN   NaN      NaN    0.0
# Zambia     Gold        0.0    NaN   NaN      NaN    NaN
#            Silver      0.0    NaN   NaN      NaN    NaN
#            Bronze      2.0    NaN   NaN      NaN    NaN
#
# [288 rows x 5 columns]

# %%
gender_flat = gender_counts.unstack(
    "Gender", fill_value=0
)  # Gender becomes outer column level

# %%
gender_flat.columns = [f"{medal}_{gender}" for medal, gender in gender_flat.columns]
gender_flat.reset_index(inplace=True)

# %%
gender_flat = gender_flat.reset_index(drop=True)
# Merge with your existing medal_counts
medal_counts = medal_counts.merge(gender_flat, on=["Committee"], how="left")

# %%
df_flags = pd.read_csv("./input/flags.csv")
df_flags.head(2)
# Out:
#   Committee Code Flag
# 0   Albania  ALB   🇦🇱
# 1   Algeria  ALG   🇩🇿

# %%
medal_counts = medal_counts.merge(df_flags[["Code", "Flag"]], on="Code")

# %%
medal_counts["Committee"] = medal_counts["Flag"] + " " + medal_counts["Committee"]

# %%
medal_counts = medal_counts.drop(columns=["Code", "Flag"])

# %%
proper_order = [
    "Committee",
    "Total",
    "Gold",
    "Silver",
    "Bronze",
    "Gold_Men",
    "Silver_Men",
    "Bronze_Men",
    "Gold_Women",
    "Silver_Women",
    "Bronze_Women",
    "Gold_Mixed",
    "Silver_Mixed",
    "Bronze_Mixed",
    "Gold_Open",
    "Silver_Open",
    "Bronze_Open",
]

# Reorder the dataframe
medal_counts = medal_counts[proper_order]

# %%
table = (
    GT(medal_counts.head(10), rowname_col="Committee")
    .tab_header(
        title="Paris 2024 Medals - Top 10",
        subtitle="Medals by Committee | Total and by Gender",
    )
    .tab_spanner(label="Total", columns=["Total", "Gold", "Silver", "Bronze"])
    .tab_spanner(label="Men", columns=["Gold_Men", "Silver_Men", "Bronze_Men"])
    .tab_spanner(label="Women", columns=["Gold_Women", "Silver_Women", "Bronze_Women"])
    .tab_spanner(label="Mixed", columns=["Gold_Mixed", "Silver_Mixed", "Bronze_Mixed"])
    .tab_spanner(label="Open", columns=["Gold_Open", "Silver_Open", "Bronze_Open"])
    .cols_label(
        Total="All",
        Gold="🥇",
        Silver="🥈",
        Bronze="🥉",
        Gold_Men="🥇",
        Silver_Men="🥈",
        Bronze_Men="🥉",
        Gold_Women="🥇",
        Silver_Women="🥈",
        Bronze_Women="🥉",
        Gold_Mixed="🥇",
        Silver_Mixed="🥈",
        Bronze_Mixed="🥉",
        Gold_Open="🥇",
        Silver_Open="🥈",
        Bronze_Open="🥉",
    )
    .tab_style(
        style=style.fill(color="#C6BCBC"),
        locations=loc.body(columns=["Total"]),
    )
    .tab_style(
        style=style.fill(color="#fefefe"),
        locations=loc.body(columns=["Gold", "Silver", "Bronze"]),
    )
    .tab_style(
        style=style.fill(color="#dbd9e9"),
        locations=loc.body(columns=["Gold_Men", "Silver_Men", "Bronze_Men"]),
    )
    .tab_style(
        style=style.fill(color="#ffb6b6"),
        locations=loc.body(columns=["Gold_Women", "Silver_Women", "Bronze_Women"]),
    )
    .tab_style(
        style=style.fill(color="#fefefe"),
        locations=loc.body(columns=["Gold_Mixed", "Silver_Mixed", "Bronze_Mixed"]),
    )
    .tab_style(
        style=style.fill(color="#efefef"),
        locations=loc.body(columns=["Gold_Open", "Silver_Open", "Bronze_Open"]),
    )
)

table
# Out:
# GT(_tbl_data=          Committee  Total  Gold  Silver  Bronze  Gold_Men  Silver_Men  \
# 0  🇺🇸 United States    252    80      88      84        26          32
# 1          🇨🇳 China    182    80      54      48        34          20
# 2          🇯🇵 Japan     90    40      24      26        24          14
# 3      🇦🇺 Australia    106    36      38      32        10          18
# 4         🇫🇷 France    128    32      52      44        22          28
# 5    🇳🇱 Netherlands     68    30      14      24        12           4
# 6  🇬🇧 Great Britain    130    28      44      58        12          30
# 7          🇮🇹 Italy     80    24      26      30         6          18
# 8        🇩🇪 Germany     66    24      26      16         8          10
# 9    🇳🇿 New Zealand     40    20      14       6         4           6
#
#    Bronze_Men  Gold_Women  Silver_Women  Bronze_Women  Gold_Mixed  \
# 0          46          52            46            36           2
# 1          14          38            30            32           6
# 2           8          16             6            14           0
# 3          12          26            18            16           0
# 4          26           8            22            16           2
# 5           6          16            10            16           2
# 6          18          12            14            30           0
# 7          22          14             8             8           4
# 8           4           6            12            12           2
# 9           0          16             8             4           0
#
#    Silver_Mixed  Bronze_Mixed  Gold_Open  Silver_Open  Bronze_Open
# 0             6             2          0            2            0
# 1             4             2          1            0            0
# 2             4             2          0            0            1
# 3             0             4          0            1            0
# 4             0             0          0            1            1
# 5             0             0          0            0            1
# 6             0             4          2            0            3
# 7             0             0          0            0            0
# 8             2             0          4            1            0
# 9             0             2          0            0            0  , _body=<great_tables._gt_data.Body object at 0x747bc84adb80>, _boxhead=Boxhead([ColInfo(var='Committee', type=<ColInfoTypeEnum.stub: 2>, column_label='Committee', column_align='left', column_width=None), ColInfo(var='Total', type=<ColInfoTypeEnum.default: 1>, column_label='All', column_align='right', column_width=None), ColInfo(var='Gold', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None), ColInfo(var='Gold_Men', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver_Men', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze_Men', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None), ColInfo(var='Gold_Women', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver_Women', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze_Women', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None), ColInfo(var='Gold_Mixed', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver_Mixed', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze_Mixed', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None), ColInfo(var='Gold_Open', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver_Open', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze_Open', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x747bc2f62270>, _spanners=Spanners([SpannerInfo(spanner_id='Total', spanner_level=0, spanner_label='Total', spanner_units=None, spanner_pattern=None, vars=['Total', 'Gold', 'Silver', 'Bronze'], built=None), SpannerInfo(spanner_id='Men', spanner_level=0, spanner_label='Men', spanner_units=None, spanner_pattern=None, vars=['Gold_Men', 'Silver_Men', 'Bronze_Men'], built=None), SpannerInfo(spanner_id='Women', spanner_level=0, spanner_label='Women', spanner_units=None, spanner_pattern=None, vars=['Gold_Women', 'Silver_Women', 'Bronze_Women'], built=None), SpannerInfo(spanner_id='Mixed', spanner_level=0, spanner_label='Mixed', spanner_units=None, spanner_pattern=None, vars=['Gold_Mixed', 'Silver_Mixed', 'Bronze_Mixed'], built=None), SpannerInfo(spanner_id='Open', spanner_level=0, spanner_label='Open', spanner_units=None, spanner_pattern=None, vars=['Gold_Open', 'Silver_Open', 'Bronze_Open'], built=None)]), _heading=Heading(title='Paris 2024 Medals - Top 10', subtitle='Medals by Committee | Total and by Gender', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=['Total'], rows=None, mask=None), grpname=None, colname='Total', rownum=0, colnum=None, styles=[CellStyleFill(color='#C6BCBC')]), StyleInfo(locname=LocBody(columns=['Total'], rows=None, mask=None), grpname=None, colname='Total', rownum=1, colnum=None, styles=[CellStyleFill(color='#C6BCBC')]), StyleInfo(locname=LocBody(columns=['Total'], rows=None, mask=None), grpname=None, colname='Total', rownum=2, colnum=None, styles=[CellStyleFill(color='#C6BCBC')]), StyleInfo(locname=LocBody(columns=['Total'], rows=None, mask=None), grpname=None, colname='Total', rownum=3, colnum=None, styles=[CellStyleFill(color='#C6BCBC')]), St ...

# %%
table.save("./output/country_medals.png", scale=4)
# Out:
# GT(_tbl_data=          Committee  Total  Gold  Silver  Bronze  Gold_Men  Silver_Men  \
# 0  🇺🇸 United States    252    80      88      84        26          32
# 1          🇨🇳 China    182    80      54      48        34          20
# 2          🇯🇵 Japan     90    40      24      26        24          14
# 3      🇦🇺 Australia    106    36      38      32        10          18
# 4         🇫🇷 France    128    32      52      44        22          28
# 5    🇳🇱 Netherlands     68    30      14      24        12           4
# 6  🇬🇧 Great Britain    130    28      44      58        12          30
# 7          🇮🇹 Italy     80    24      26      30         6          18
# 8        🇩🇪 Germany     66    24      26      16         8          10
# 9    🇳🇿 New Zealand     40    20      14       6         4           6
#
#    Bronze_Men  Gold_Women  Silver_Women  Bronze_Women  Gold_Mixed  \
# 0          46          52            46            36           2
# 1          14          38            30            32           6
# 2           8          16             6            14           0
# 3          12          26            18            16           0
# 4          26           8            22            16           2
# 5           6          16            10            16           2
# 6          18          12            14            30           0
# 7          22          14             8             8           4
# 8           4           6            12            12           2
# 9           0          16             8             4           0
#
#    Silver_Mixed  Bronze_Mixed  Gold_Open  Silver_Open  Bronze_Open
# 0             6             2          0            2            0
# 1             4             2          1            0            0
# 2             4             2          0            0            1
# 3             0             4          0            1            0
# 4             0             0          0            1            1
# 5             0             0          0            0            1
# 6             0             4          2            0            3
# 7             0             0          0            0            0
# 8             2             0          4            1            0
# 9             0             2          0            0            0  , _body=<great_tables._gt_data.Body object at 0x747bc84adb80>, _boxhead=Boxhead([ColInfo(var='Committee', type=<ColInfoTypeEnum.stub: 2>, column_label='Committee', column_align='left', column_width=None), ColInfo(var='Total', type=<ColInfoTypeEnum.default: 1>, column_label='All', column_align='right', column_width=None), ColInfo(var='Gold', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None), ColInfo(var='Gold_Men', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver_Men', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze_Men', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None), ColInfo(var='Gold_Women', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver_Women', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze_Women', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None), ColInfo(var='Gold_Mixed', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver_Mixed', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze_Mixed', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None), ColInfo(var='Gold_Open', type=<ColInfoTypeEnum.default: 1>, column_label='🥇', column_align='right', column_width=None), ColInfo(var='Silver_Open', type=<ColInfoTypeEnum.default: 1>, column_label='🥈', column_align='right', column_width=None), ColInfo(var='Bronze_Open', type=<ColInfoTypeEnum.default: 1>, column_label='🥉', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x747bc2f62270>, _spanners=Spanners([SpannerInfo(spanner_id='Total', spanner_level=0, spanner_label='Total', spanner_units=None, spanner_pattern=None, vars=['Total', 'Gold', 'Silver', 'Bronze'], built=None), SpannerInfo(spanner_id='Men', spanner_level=0, spanner_label='Men', spanner_units=None, spanner_pattern=None, vars=['Gold_Men', 'Silver_Men', 'Bronze_Men'], built=None), SpannerInfo(spanner_id='Women', spanner_level=0, spanner_label='Women', spanner_units=None, spanner_pattern=None, vars=['Gold_Women', 'Silver_Women', 'Bronze_Women'], built=None), SpannerInfo(spanner_id='Mixed', spanner_level=0, spanner_label='Mixed', spanner_units=None, spanner_pattern=None, vars=['Gold_Mixed', 'Silver_Mixed', 'Bronze_Mixed'], built=None), SpannerInfo(spanner_id='Open', spanner_level=0, spanner_label='Open', spanner_units=None, spanner_pattern=None, vars=['Gold_Open', 'Silver_Open', 'Bronze_Open'], built=None)]), _heading=Heading(title='Paris 2024 Medals - Top 10', subtitle='Medals by Committee | Total and by Gender', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=['Total'], rows=None, mask=None), grpname=None, colname='Total', rownum=0, colnum=None, styles=[CellStyleFill(color='#C6BCBC')]), StyleInfo(locname=LocBody(columns=['Total'], rows=None, mask=None), grpname=None, colname='Total', rownum=1, colnum=None, styles=[CellStyleFill(color='#C6BCBC')]), StyleInfo(locname=LocBody(columns=['Total'], rows=None, mask=None), grpname=None, colname='Total', rownum=2, colnum=None, styles=[CellStyleFill(color='#C6BCBC')]), StyleInfo(locname=LocBody(columns=['Total'], rows=None, mask=None), grpname=None, colname='Total', rownum=3, colnum=None, styles=[CellStyleFill(color='#C6BCBC')]), St ...

# %%
table.write_raw_html("./output/country_medals.html")

# %% [markdown]
# ## Charts

# %%
top_ten = medal_counts.head(10)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('cairo')

plt.bar(
    top_ten["Committee"],
    top_ten["Total"],
    color="skyblue",
    edgecolor="black",
)
plt.xticks(rotation=45, ha="right")
plt.xlabel("Committee")
plt.ylabel("Total 🥇")
plt.title("Total Medals by Committee 🇯🇵🇨🇦🇺🇸")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/mess/lib/python3.12/site-packages/matplotlib/backends/backend_cairo.py:16
#      15 try:
# ---> 16     import cairo
#      17     if cairo.version_info < (1, 14, 0):  # Introduced set_device_scale.
#
# ModuleNotFoundError: No module named 'cairo'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/mess/lib/python3.12/site-packages/matplotlib/backends/backend_cairo.py:22
#      21 try:
# ---> 22     import cairocffi as cairo
#      23 except ImportError as err:
#
# ModuleNotFoundError: No module named 'cairocffi'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 3
#       1 import matplotlib.pyplot as plt
#       2 import matplotlib
# ----> 3 matplotlib.use('cairo')
#       5 plt.bar(
#       6     top_ten["Committee"],
#       7     top_ten["Total"],
#       8     color="skyblue",
#       9     edgecolor="black",
#      10 )
#      11 plt.xticks(rotation=45, ha="right")
#
# File ~/miniconda3/envs/mess/lib/python3.12/site-packages/matplotlib/__init__.py:1281, in use(backend, force)
#    1276 if plt is not None:
#    1277     try:
#    1278         # we need this import check here to re-raise if the
#    1279         # user does not have the libraries to support their
#    1280         # chosen backend installed.
# -> 1281         plt.switch_backend(name)
#    1282     except ImportError:
#    1283         if force:
#
# File ~/miniconda3/envs/mess/lib/python3.12/site-packages/matplotlib/pyplot.py:425, in switch_backend(newbackend)
#     422         return
#     423 old_backend = rcParams._get('backend')  # get without triggering backend resolution
# --> 425 module = backend_registry.load_backend_module(newbackend)
#     426 canvas_class = module.FigureCanvas
#     428 required_framework = canvas_class.required_interactive_framework
#
# File ~/miniconda3/envs/mess/lib/python3.12/site-packages/matplotlib/backends/registry.py:317, in BackendRegistry.load_backend_module(self, backend)
#     303 """
#     304 Load and return the module containing the specified backend.
#     305
#    (...)    314     Module containing backend.
#     315 """
#     316 module_name = self._backend_module_name(backend)
# --> 317 return importlib.import_module(module_name)
#
# File ~/miniconda3/envs/mess/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/mess/lib/python3.12/site-packages/matplotlib/backends/backend_cairo.py:24
#      22         import cairocffi as cairo
#      23     except ImportError as err:
# ---> 24         raise ImportError(
#      25             "cairo backend requires that pycairo>=1.14.0 or cairocffi "
#      26             "is installed") from err
#      28 from .. import _api, cbook, font_manager
#      29 from matplotlib.backend_bases import (
#      30     _Backend, FigureCanvasBase, FigureManagerBase, GraphicsContextBase,
#      31     RendererBase)
#
# ImportError: cairo backend requires that pycairo>=1.14.0 or cairocffi is installed
