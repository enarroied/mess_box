# %% [markdown]
# # Example given in Melodi's documentation
#
# I'm running this locally to see what happen

# %%
import json

import pandas as pd
import requests

# %%
api_url = "https://api.insee.fr/melodi/data/DS_POPULATIONS_REFERENCE?GEO=DEP-44"

get_data = requests.get(api_url, verify=False)
data_from_net = get_data.content
data = json.loads(data_from_net)
# Out:
# /home/eric/miniconda3/envs/mess/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.insee.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# Extraction des informations du jeu de données
title = data["title"]["fr"]
identifier = data["identifier"]

# Extraction des observations du jeu de données filtré, sur lesquelles on va boucler
observations = data["observations"]
extracted_data = []

# %%
# Boucle de lecture des observations dans le json
for obs in observations:
    dimensions = obs["dimensions"]

    # Suivant les jeux de données attributes est présent ou non
    if "attributes" in obs:
        attributes = obs["attributes"]
    else:
        attributes = None

    # Suivant les jeux de données value peut être absent
    if "value" in obs["measures"]["OBS_VALUE_NIVEAU"]:
        measures = obs["measures"]["OBS_VALUE_NIVEAU"]["value"]
    else:
        mesures = None

    # on rassemble tout dans un objet
    if "attributes" in obs:
        combined_data = {**dimensions, **attributes, "OBS_VALUE_NIVEAU": measures}
    else:
        combined_data = {**dimensions, "OBS_VALUE_NIVEAU": measures}

    extracted_data.append(combined_data)

# %%
# Création d'un dataframe python
df = pd.DataFrame(extracted_data)

print(f"Jeu de données : {identifier} \nTitre : {title} ")
print(df)
# Out:
# Jeu de données : DS_POPULATIONS_REFERENCE
# Titre : Populations de référence
#            GEO FREQ TIME_PERIOD POPREF_MEASURE  OBS_VALUE_NIVEAU
# 0  2025-DEP-44    A        2023           PTOT         1517043.0
# 1  2025-DEP-44    A        2023           PCAP           29473.0
# 2  2025-DEP-44    A        2023           PMUN         1487570.0

# %% [markdown]
# ## Searching the catalog
#
# Swagger doc: https://portail-api.insee.fr/catalog/api/a890b735-159c-4c91-90b7-35159c7c9126/doc?page=ee625968-272a-4637-a259-68272aa63766

# %%
api_url = "https://api.insee.fr/melodi/catalog/all"

get_data = requests.get(api_url, verify=False)
data_from_net = get_data.content
data = json.loads(data_from_net)
# Out:
# /home/eric/miniconda3/envs/mess/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.insee.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
for item in data:
    identifier = item.get("identifier")
    abstract = item.get("abstract")
    product = item.get("product")

    print(identifier)
    print(abstract)
    print(product)
# Out:
# DD_CNA_AGREGATS
# [{'content': "Données annuelles de Produit Intérieur Brut (PIB) et grands agrégats économiques associés au PIB: revenu national brut (RNB), capacité ou besoin de financement de la Nation, grandes composantes de l'équilibre de l'offre et de la demande, ventilation des facteurs de production.", 'lang': 'fr'}, {'content': "Annual data on Gross Domestic Product (GDP) and the main economic aggregates associated with GDP: gross national income (GNI), the nation's capacity or need for financing, the main components of the balance between supply and demand, and the breakdown of factors of production.", 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_AGREGATS/DD_CNA_AGREGATS_CSV_FR', 'byteSize': 1895856, 'format': 'CSV', 'id': 'DD_CNA_AGREGATS_CSV_FR', 'issued': '2024-07-18T15:46:53', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-08-29T13:38:30', 'packageFormat': 'application/zip', 'title': 'Produit Intérieur Brut (PIB) et grands agrégats économiques'}]
# DD_CNA_APU
# [{'content': 'Données concernant le secteur institutionnel des administrations publiques.', 'lang': 'fr'}, {'content': 'Data dealing with the public administration institutional sector.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_APU/DD_CNA_APU_CSV_FR', 'byteSize': 543172, 'format': 'CSV', 'id': 'DD_CNA_APU_CSV_FR', 'issued': '2025-06-24T09:38:10', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-06-24T09:38:10', 'packageFormat': 'application/zip', 'title': 'Comptes des administrations publiques'}]
# DD_CNA_BRANCHES
# [{'content': "Données annuelles sur l'activité des branches au sein des comptes de production et d'exploitation, ainsi que d’emploi et de productivité apparente du travail.", 'lang': 'fr'}, {'content': 'Annual data on the activity of branches within the production and operating accounts, as well as employment and apparent labour productivity.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_BRANCHES/DD_CNA_BRANCHES_CSV_FR', 'byteSize': 3551601, 'format': 'CSV', 'id': 'DD_CNA_BRANCHES_CSV_FR', 'issued': '2024-11-22T13:11:59', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-05-27T17:45:13', 'packageFormat': 'application/zip', 'title': "Activité des branches de l'économie"}]
# DD_CNA_CONSO_MENAGES_COICOP
# [{'content': 'Données annuelles de consommation finale effective des ménages par fonction de consommation (nomenclature COICOP).', 'lang': 'fr'}, {'content': 'Annual data on actual final household consumption by consumption function (COICOP nomenclature).', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_CONSO_MENAGES_COICOP/DD_CNA_CONSO_MENAGES_COICOP_CSV_FR', 'byteSize': 2120825, 'format': 'CSV', 'id': 'DD_CNA_CONSO_MENAGES_COICOP_CSV_FR', 'issued': '2024-07-18T15:47:00', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-05-27T19:16:08', 'packageFormat': 'application/zip', 'title': 'Consommation des ménages par fonction'}]
# DD_CNA_CONSO_MENAGES_PRODUITS
# [{'content': 'Données annuelles de consommation finale effective des ménages par produit et par durabilité.', 'lang': 'fr'}, {'content': 'Annual data on actual final household consumption by product and sustainability.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_CONSO_MENAGES_PRODUITS/DD_CNA_CONSO_MENAGES_PRODUITS_CSV_FR', 'byteSize': 8906047, 'format': 'CSV', 'id': 'DD_CNA_CONSO_MENAGES_PRODUITS_CSV_FR', 'issued': '2024-09-12T16:38:38', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-05-27T19:16:34', 'packageFormat': 'application/zip', 'title': 'Consommation des ménages par produit'}]
# DD_CNA_ECH_EXT
# [{'content': 'Données annuelles d’échanges extérieurs de la France (importations, exportations, solde, zones géographiques).', 'lang': 'fr'}, {'content': "Annual data on France's foreign trade (imports, exports, balance, geographical areas).", 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_ECH_EXT/DD_CNA_ECH_EXT_CSV_FR', 'byteSize': 610344, 'format': 'CSV', 'id': 'DD_CNA_ECH_EXT_CSV_FR', 'issued': '2024-07-18T15:46:26', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-05-27T19:17:04', 'packageFormat': 'application/zip', 'title': 'Échanges extérieurs'}]
# DD_CNA_PATRIMOINE
# [{'content': 'Données annuelles sur le compte de patrimoine.', 'lang': 'fr'}, {'content': 'This dataset contains annual asset account data.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_PATRIMOINE/DD_CNA_PATRIMOINE_CSV_FR', 'byteSize': 2010563, 'format': 'CSV', 'id': 'DD_CNA_PATRIMOINE_CSV_FR', 'issued': '2025-07-29T09:55:16', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-09-05T14:10:36', 'packageFormat': 'application/zip', 'title': 'Comptes de patrimoine'}]
# DD_CNA_PATRIMOINE_BRANCHES
# [{'content': 'Données annuelles sur le compte de patrimoine ventilées par branches.', 'lang': 'fr'}, {'content': 'This dataset contains annual asset account data by branch.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_PATRIMOINE_BRANCHES/DD_CNA_PATRIMOINE_BRANCHES_CSV_FR', 'byteSize': 4758814, 'format': 'CSV', 'id': 'DD_CNA_PATRIMOINE_BRANCHES_CSV_FR', 'issued': '2024-12-18T17:47:17', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-07-28T17:41:40', 'packageFormat': 'application/zip', 'title': 'Comptes de patrimoine par branches'}]
# DD_CNA_REBS
# [{'content': "Données annuelles sur l'équilibre emploi-ressource par produit et service.", 'lang': 'fr'}, {'content': 'Yearly data in supply and use in goods and services.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_REBS/DD_CNA_REBS_CSV_FR', 'byteSize': 2713234, 'format': 'CSV', 'id': 'DD_CNA_REBS_CSV_FR', 'issued': '2025-05-27T15:26:29', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-05-27T15:26:29', 'packageFormat': 'application/zip', 'title': 'Ressources et emplois de biens et services'}]
# DD_CNA_SUT
# [{'content': 'Données du tableau entrées-sorties des comptes nationaux annuels.', 'lang': 'fr'}, {'content': 'Data from the supply and use table  table of the annual national accounts.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_SUT/DD_CNA_SUT_CSV_FR', 'byteSize': 3455576, 'format': 'CSV', 'id': 'DD_CNA_SUT_CSV_FR', 'issued': '2025-05-27T16:03:33', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-05-27T16:03:33', 'packageFormat': 'application/zip', 'title': 'Tableau des entrées-sorties (TES)'}]
# DD_CNA_TEE
# [{'content': "Données sur l'ensemble des opérations relatives aux secteurs institutionnels.", 'lang': 'fr'}, {'content': 'Data on all operations relating to institutional sectors.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_CNA_TEE/DD_CNA_TEE_CSV_FR', 'byteSize': 3667467, 'format': 'CSV', 'id': 'DD_CNA_TEE_CSV_FR', 'issued': '2024-12-20T11:01:23', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-05-27T19:29:05', 'packageFormat': 'application/zip', 'title': "Tableau économique d'ensemble"}]
# DD_EEC_ANNUEL
# [{'content': 'Données annuelles sur la population totale, la population active, l’emploi, les caractéristiques de l’emploi ainsi que sur le chômage et le halo autour du chômage. ', 'lang': 'fr'}, {'content': 'Annual data on total population, active population, employment and its caracteristics, unemployment and its halo.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_EEC_ANNUEL/DD_EEC_ANNUEL_2024_CSV_FR', 'byteSize': 155232, 'format': 'CSV', 'id': 'DD_EEC_ANNUEL_2024_CSV_FR', 'issued': '2025-06-27T11:11:23', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-07-17T09:38:53', 'packageFormat': 'application/zip', 'title': 'Activité, emploi et chômage - résultats annuels 2024'}]
# DD_EEC_SERIES
# [{'content': 'Séries longues sur la population active, l’emploi, le chômage et le halo autour du chômage.', 'lang': 'fr'}, {'content': 'Time series on the active population, employment, unemployment and the halo around unemployment.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DD_EEC_SERIES/DD_EEC_SERIES_CSV_FR', 'byteSize': 515457, 'format': 'CSV', 'id': 'DD_EEC_SERIES_CSV_FR', 'issued': '2025-07-03T13:44:16', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-07-03T13:44:16', 'packageFormat': 'application/zip', 'title': 'Activité, emploi et chômage - séries longues'}]
# DS_ANTIPOL
# [{'content': "Données sur les montants d'études, d'investissements (tous les ans) et de dépenses courantes (tous les trois ans) des établissements industriels pour réduire leur impact sur l'environnement.", 'lang': 'fr'}, {'content': 'Data on the amounts spent by industrial establishments on studies, investments (every year) and current expenditure (every three years) to reduce their impact on the environment. ', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ANTIPOL/DS_ANTIPOL_2023_CSV_FR', 'byteSize': 11615, 'format': 'CSV', 'id': 'DS_ANTIPOL_2023_CSV_FR', 'issued': '2025-11-26T12:07:10', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-11-26T12:07:10', 'packageFormat': 'application/zip', 'title': "Enquête annuelle sur les investissements pour protéger l'environnement (Antipol)"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ANTIPOL/ANTIPOL_2023_GLOBAL_T0_FR', 'byteSize': 10852, 'format': 'XLSX', 'id': 'ANTIPOL_2023_GLOBAL_T0_FR', 'issued': '2025-11-27T10:51:42', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-11-27T10:51:42', 'title': "Ensemble des études, investissements et dépenses courantes pour protéger l'environnement depuis 2007"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ANTIPOL/ANTIPOL_2023_GLOBAL_T1-T4_FR', 'byteSize': 15180, 'format': 'XLSX', 'id': 'ANTIPOL_2023_GLOBAL_T1-T4_FR', 'issued': '2025-11-27T10:51:43', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-11-27T10:51:43', 'title': "Ensemble des études et investissements réalisés pour protéger l'environnement en 2023"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ANTIPOL/ANTIPOL_2023_INVEST_T1-T3_FR', 'byteSize': 13508, 'format': 'XLSX', 'id': 'ANTIPOL_2023_INVEST_T1-T3_FR', 'issued': '2025-11-27T10:51:43', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-11-27T10:51:43', 'title': "Ensemble des investissements (spécifiques et intégrés) réalisés pour protéger l'environnement en 2023, par domaine"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ANTIPOL/ANTIPOL_2023_INVEST_T4-T6_FR', 'byteSize': 12152, 'format': 'XLSX', 'id': 'ANTIPOL_2023_INVEST_T4-T6_FR', 'issued': '2025-11-27T10:51:43', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-11-27T10:51:43', 'title': "Les investissements spécifiques réalisés pour protéger l'environnement en 2023, par nature"}]
# DS_BPE
# [{'content': "Dénombrement des équipements par type d'équipement (commerce, services, santé...) et par niveau géographique.", 'lang': 'fr'}, {'content': '', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/DS_BPE_2024_CSV_FR', 'byteSize': 13413554, 'format': 'CSV', 'id': 'DS_BPE_2024_CSV_FR', 'issued': '2025-07-09T16:06:09', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-07-09T16:06:09', 'packageFormat': 'application/zip', 'title': 'Dénombrement des équipements (commerce, sport, services, santé…)'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_COMMERCE_FR', 'byteSize': 2351413, 'format': 'XLSX', 'id': 'BPE_COMMERCE_FR', 'issued': '2025-07-09T16:29:10', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:29:10', 'title': 'BPE : B-commerces'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_COMMERCE_EN', 'byteSize': 2351379, 'format': 'XLSX', 'id': 'BPE_COMMERCE_EN', 'issued': '2025-07-09T16:35:27', 'language': 'EN', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:35:27', 'title': 'BPE : B-retail trade'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_ENSEIGNEMENT_FR', 'byteSize': 1731971, 'format': 'XLSX', 'id': 'BPE_ENSEIGNEMENT_FR', 'issued': '2025-07-09T16:28:41', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:28:41', 'title': 'BPE : C-enseignement'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_ENSEIGNEMENT_EN', 'byteSize': 1731936, 'format': 'XLSX', 'id': 'BPE_ENSEIGNEMENT_EN', 'issued': '2025-07-09T16:33:42', 'language': 'EN', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:33:42', 'title': 'BPE : C-education'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_SANTE_ACTION_SOCIALE_FR', 'byteSize': 4116675, 'format': 'XLSX', 'id': 'BPE_SANTE_ACTION_SOCIALE_FR', 'issued': '2025-07-09T16:28:19', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:28:19', 'title': 'BPE : D-santé et action sociale'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_SANTE_ACTION_SOCIALE_EN', 'byteSize': 4116634, 'format': 'XLSX', 'id': 'BPE_SANTE_ACTION_SOCIALE_EN', 'issued': '2025-07-09T16:33:22', 'language': 'EN', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:33:22', 'title': 'BPE : D-health and social services'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_SERVICE_PARTICULIER_FR', 'byteSize': 4922946, 'format': 'XLSX', 'id': 'BPE_SERVICE_PARTICULIER_FR', 'issued': '2025-07-09T16:39:41', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:39:41', 'title': 'BPE : A-services pour les particuliers'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_SERVICE_PARTICULIER_EN', 'byteSize': 4922932, 'format': 'XLSX', 'id': 'BPE_SERVICE_PARTICULIER_EN', 'issued': '2025-07-09T16:32:39', 'language': 'EN', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:32:39', 'title': 'BPE : A-personal services'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_SPORT_LOISIR_CULTURE_FR', 'byteSize': 3364553, 'format': 'XLSX', 'id': 'BPE_SPORT_LOISIR_CULTURE_FR', 'issued': '2025-07-09T16:26:47', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:26:47', 'title': 'BPE : F-sports, loisirs et culture'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE/BPE_SPORT_LOISIR_CULTURE_EN', 'byteSize': 3364496, 'format': 'XLSX', 'id': 'BPE_SPORT_LOISIR_CULTURE_EN', 'issued': '2025-07-09T16:31:52', 'language': 'EN', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-09T16:31:52', 'title': 'BPE : F-sports, leisure and culture'}, {'accessURL':  ...
# DS_BPE_EDUCATION
# [{'content': "Dénombrement et capacité des équipements dans le domaine de l'enseignement par type d'équipement et par niveau géographique.", 'lang': 'fr'}, {'content': '', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE_EDUCATION/DS_BPE_EDUCATION_2024_CSV_FR', 'byteSize': 10609825, 'format': 'CSV', 'id': 'DS_BPE_EDUCATION_2024_CSV_FR', 'issued': '2025-07-10T08:32:31', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-07-10T08:32:31', 'packageFormat': 'application/zip', 'title': 'Enseignement : dénombrement et caractéristiques des équipements'}]
# DS_BPE_EVOLUTION
# [{'content': "Dénombrement et capacité des équipements dans le domaine de l'enseignement par type d'équipement et par niveau géographique.", 'lang': 'fr'}, {'content': '', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE_EVOLUTION/DS_BPE_EVOLUTION_2024_CSV_FR', 'byteSize': 6616461, 'format': 'CSV', 'id': 'DS_BPE_EVOLUTION_2024_CSV_FR', 'issued': '2025-07-09T17:03:42', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-07-09T17:03:42', 'packageFormat': 'application/zip', 'title': "Évolution du nombre d'équipements et services"}]
# DS_BPE_SPORT_CULTURE
# [{'content': "Dénombrement, caractéristiques et capacités des équipements dans le domaine du sport-loisirs-culture par type d'équipement et par niveau géographique.", 'lang': 'fr'}, {'content': '', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_BPE_SPORT_CULTURE/DS_BPE_SPORT_CULTURE_2024_CSV_FR', 'byteSize': 10224643, 'format': 'CSV', 'id': 'DS_BPE_SPORT_CULTURE_2024_CSV_FR', 'issued': '2025-07-10T08:30:15', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-07-10T08:30:15', 'packageFormat': 'application/zip', 'title': 'Sport, loisirs et culture : dénombrement, caractéristiques et capacités des équipements'}]
# DS_BTS_SAL_EQTP_SEX_AGE
# [{'content': "Salaire net mensuel en équivalent temps plein dans le secteur privé selon le sexe et l'âge, en fonction du lieu de travail à divers niveaux géographiques : commune, arrondissement municipal, arrondissement, aire d'attraction des villes 2020, bassin de vie 2022, établissement public de coopération intercommunal, unité urbaine 2020, zone d'emploi 2020, département, région, France hors Mayotte.", 'lang': 'fr'}, {'content': "Net monthly full-time equivalent salary in the private sector by gender and age, according to place of work at various geographical levels: commune, arrondissement municipal, arrondissement, aire d'attraction des villes 2020, bassin de vie 2022, établissement public de coopération intercommunal, unité urbaine 2020, zone d'emploi 2020, département, région, France excluding Mayotte.", 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_BTS_SAL_EQTP_SEX_AGE/DS_BTS_SAL_EQTP_SEX_AGE_2023_CSV_FR', 'byteSize': 5216982, 'format': 'CSV', 'id': 'DS_BTS_SAL_EQTP_SEX_AGE_2023_CSV_FR', 'issued': '2025-09-02T13:43:33', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-09-02T13:43:33', 'packageFormat': 'application/zip', 'title': "Salaires dans le secteur privé selon le sexe et l'âge au niveau communal"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BTS_SAL_EQTP_SEX_AGE/BTS_SEX_AGE_2023_FR', 'byteSize': 2494332, 'format': 'XLSX', 'id': 'BTS_SEX_AGE_2023_FR', 'issued': '2025-09-02T13:46:00', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-02T13:46:00', 'title': "Salaires dans le secteur privé selon le sexe et l'âge"}]
# DS_BTS_SAL_EQTP_SEX_PCS
# [{'content': "Salaire net mensuel en équivalent temps plein dans le secteur privé selon le sexe et la catégorie socioprofessionnelle, en fonction du lieu de travail à divers niveaux géographiques : commune, arrondissement municipal, arrondissement, aire d'attraction des villes 2020, bassin de vie 2022, établissement public de coopération intercommunal, unité urbaine 2020, zone d'emploi 2020, département, région, France hors Mayotte.", 'lang': 'fr'}, {'content': "Net monthly full-time equivalent salary in the private sector by gender and socio-professional category, according to place of work at various geographical levels: commune, arrondissement municipal, arrondissement, aire d'attraction des villes 2020, bassin de vie 2022, établissement public de coopération intercommunal, unité urbaine 2020, zone d'emploi 2020, département, région, France excluding Mayotte.", 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_BTS_SAL_EQTP_SEX_PCS/DS_BTS_SAL_EQTP_SEX_PCS_2023_CSV_FR', 'byteSize': 4395755, 'format': 'CSV', 'id': 'DS_BTS_SAL_EQTP_SEX_PCS_2023_CSV_FR', 'issued': '2025-09-02T13:43:22', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-09-02T13:43:22', 'packageFormat': 'application/zip', 'title': 'Salaires dans le secteur privé selon le sexe et la catégorie socioprofessionnelle au niveau communal'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_BTS_SAL_EQTP_SEX_PCS/BTS_SEX_PCS_2023_FR', 'byteSize': 2162563, 'format': 'XLSX', 'id': 'BTS_SEX_PCS_2023_FR', 'issued': '2025-09-02T13:47:18', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-02T13:47:18', 'title': 'Salaires dans le secteur privé selon le sexe et la catégorie socioprofessionnelle'}]
# DS_COEFF_EURO_FRANC
# [{'content': "Coefficient permettant une conversion d'un franc ou d'un euro d'une année, en euro ou franc d'une autre année. Il basé sur le calcul de l'inflation.", 'lang': 'fr'}, {'content': 'Coefficient used to convert a franc or euro of one year into a euro or franc of another year. It is based on the calculation of inflation.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_COEFF_EURO_FRANC/DS_COEFF_EURO_FRANC_CSV_FR', 'byteSize': 1790, 'format': 'CSV', 'id': 'DS_COEFF_EURO_FRANC_CSV_FR', 'issued': '2026-02-02T10:10:34', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-02-02T10:10:34', 'packageFormat': 'application/zip', 'title': "Coefficient de transformation de l'euro ou du franc d'une année, en euro ou en franc d'une autre année"}]
# DS_COMPTES_REGIONAUX
# [{'content': 'Données annuelles des comptes régionaux\xa0: Produit Intérieur Brut (PIB), valeurs ajoutées par branche et compte des ménages régionaux. Ce dernier décrit la formation du revenu disponible brut (RDB) des ménages à partir de ses composantes en détaillant le compte des ménages pour chaque région\xa0: excédent brut et revenu mixte, salaires et traitements bruts, cotisations sociales, impôts et prestations en espèces.', 'lang': 'fr'}, {'content': 'Annual data from the regional accounts: Gross Domestic Product (GDP), value added by industry and the regional household accounts. The latter describes the formation of household gross disposable income (GDI) on the basis of its components by detailing the household account for each region: ross mixed income and gross operating surplus, compensation of employees, property income, current taxes, social contributions and benefits, and other current transfers.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_COMPTES_REGIONAUX/DS_COMPTES_REGIONAUX_CSV_FR', 'byteSize': 1715692, 'format': 'CSV', 'id': 'DS_COMPTES_REGIONAUX_CSV_FR', 'issued': '2025-04-08T10:50:25', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-07-22T09:43:57', 'packageFormat': 'application/zip', 'title': 'Comptes régionaux annuels'}]
# DS_DECES_MORTALITE_SERIES
# [{'content': 'Séries chronologiques sur les décès et la mortalité au niveau départemental, régional et national.', 'lang': 'fr'}, {'content': 'Data compiling various indicators on mortality at the departmental, regional, and national levels.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_DECES_MORTALITE_SERIES/DS_DECES_MORTALITE_SERIES_CSV_FR', 'byteSize': 523004, 'format': 'CSV', 'id': 'DS_DECES_MORTALITE_SERIES_CSV_FR', 'issued': '2026-01-21T18:56:12', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-01-26T17:38:52', 'packageFormat': 'application/zip', 'title': 'Décès et mortalité - séries longues'}]
# DS_DERA_PRIVE_ANNUEL
# [{'content': 'Salaire net en équivalent temps plein dans le secteur privé ventilé par catégorie socioprofessionnelle détaillée et selon plusieurs variables (sexe, âge, secteur...).', 'lang': 'fr'}, {'content': 'Net full-time equivalent salary in the private sector broken down by detailed socio-professional category and by several variables (gender, age, sector, etc.).', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_DERA_PRIVE_ANNUEL/DS_DERA_PRIVE_ANNUEL_2024_CSV_FR', 'byteSize': 374565, 'format': 'CSV', 'id': 'DS_DERA_PRIVE_ANNUEL_2024_CSV_FR', 'issued': '2025-12-04T12:05:38', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-12-04T12:05:38', 'packageFormat': 'application/zip', 'title': 'Salaires dans le secteur privé par catégorie socioprofessionnelle détaillée'}]
# DS_DERA_PRIVE_SERIES_LONGUES
# [{'content': 'Salaires nets dans le secteur privé depuis 1951 (pour les temps complets) ou 1996 (pour tous volumes de travail, convertis en équivalent temps plein), ventilés selon plusieurs variables (sexe, âge, secteur...).', 'lang': 'fr'}, {'content': 'Net wages in the private sector since 1951 (for full-time workers) or 1996 (for all work volumes, converted to full-time equivalents), broken down by several variables (gender, age, sector, etc.).', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_DERA_PRIVE_SERIES_LONGUES/DS_DERA_PRIVE_SERIES_LONGUES_CSV_FR', 'byteSize': 135181, 'format': 'CSV', 'id': 'DS_DERA_PRIVE_SERIES_LONGUES_CSV_FR', 'issued': '2025-12-04T14:35:50', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-12-04T14:35:50', 'packageFormat': 'application/zip', 'title': 'Séries longues de salaires dans le secteur privé'}]
# DS_DERA_PUBLIC_ANNUEL
# [{'content': 'Salaire net en équivalent temps plein dans la fonction public ventilé par profession et selon plusieurs variables (sexe, âge, secteur...), pour la France hors Mayotte.', 'lang': 'fr'}, {'content': 'Net full-time equivalent salary in the public sector broken down by occupation and by several variables (gender, age, sector, etc.) in France excluding Mayotte.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_DERA_PUBLIC_ANNUEL/DS_DERA_PUBLIC_ANNUEL_2023_CSV_FR', 'byteSize': 40879, 'format': 'CSV', 'id': 'DS_DERA_PUBLIC_ANNUEL_2023_CSV_FR', 'issued': '2025-12-04T12:05:31', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-12-04T12:05:31', 'packageFormat': 'application/zip', 'title': 'Salaires dans la fonction publique par par catégorie socioprofessionnelle détaillée'}]
# DS_DERA_PUBLIC_SERIES_LONGUES
# [{'content': 'Salaires nets dans le secteur public depuis 1995, ventilés selon plusieurs variables (sexe, âge, secteur...), pour la France hors Mayotte.', 'lang': 'fr'}, {'content': 'Net wages in the public sector since 1995, broken down by several variables (gender, age, sector, etc.) in France excluding Mayotte.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_DERA_PUBLIC_SERIES_LONGUES/DS_DERA_PUBLIC_SERIES_LONGUES_CSV_FR', 'byteSize': 18740, 'format': 'CSV', 'id': 'DS_DERA_PUBLIC_SERIES_LONGUES_CSV_FR', 'issued': '2025-12-04T12:05:23', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-12-04T12:05:23', 'packageFormat': 'application/zip', 'title': 'Séries longues des salaires dans la fonction publique '}]
# DS_DEVDUR
# [{'content': "Données contenant les 98 indicateurs des 17 objectifs de développement durable (ODD) adoptés par l'assemblée générale de l’Organisation des Nations unies (ONU) pour la période 2015-2030.", 'lang': 'fr'}, {'content': 'Data from the 98 indicators of the 17 Sustainable Development Goals (SDGs) adopted by the United Nations (UN) General Assembly for the period 2015-2030.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_DEVDUR/DS_DEVDUR_CSV_FR', 'byteSize': 97592, 'format': 'CSV', 'id': 'DS_DEVDUR_CSV_FR', 'issued': '2025-06-19T11:32:21', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-06-19T11:32:21', 'packageFormat': 'application/zip', 'title': "Indicateurs d'objectifs de développement durable"}]
# DS_EACEI
# [{'content': "Cette enquête fournit les quantités consommées par type d'énergie, les coûts afférents, et la répartition par usage de chaque énergie utilisée. Le champ de l’enquête regroupe les établissements de plus de 20 salariés dans l’industrie. ", 'lang': 'fr'}, {'content': 'This survey provides the quantities consumed by type of energy, the related costs, and the breakdown by use of each energy used. The survey covers industrial establishments with more than 20 employees. ', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/DS_EACEI_2023_CSV_FR', 'byteSize': 42967, 'format': 'CSV', 'id': 'DS_EACEI_2023_CSV_FR', 'issued': '2025-10-24T17:52:33', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-10-24T17:52:33', 'packageFormat': 'application/zip', 'title': "Enquête annuelle sur les consommations d'énergie dans l'industrie (EACEI)"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/EACEI_CCN_CONSO_ENERGIE_FR', 'byteSize': 7783, 'format': 'XLSX', 'id': 'EACEI_CCN_CONSO_ENERGIE_FR', 'issued': '2025-10-24T17:58:48', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-10-24T17:58:48', 'title': "Chiffres clés relatifs à la consommation d'énergie par type et activité"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/EACEI_CCN_PRIX_COMB_SL_FR', 'byteSize': 6871, 'format': 'XLSX', 'id': 'EACEI_CCN_PRIX_COMB_SL_FR', 'issued': '2025-10-24T17:58:48', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-10-24T17:58:48', 'title': 'Chiffres clés relatifs au prix moyen des combustibles industriels'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/EACEI_SL_T1_FR', 'byteSize': 12203, 'format': 'XLSX', 'id': 'EACEI_SL_T1_FR', 'issued': '2025-10-24T17:58:50', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-10-24T17:58:50', 'title': "Chiffres clés relatifs à la consommation d'énergie dans l'industrie (y compris IAA)"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/EACEI_T1_FR', 'byteSize': 17093, 'format': 'XLSX', 'id': 'EACEI_T1_FR', 'issued': '2025-10-24T17:58:48', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-10-24T17:58:48', 'title': "Consommation d'énergie en milliers de tonnes-équivalent-pétrole (kTEP) et nombre d'établissements"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/EACEI_T2_FR', 'byteSize': 25296, 'format': 'XLSX', 'id': 'EACEI_T2_FR', 'issued': '2025-10-24T17:58:49', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-10-24T17:58:49', 'title': "Achats et consommation en unité propre, valeur d'achat et prix moyen des produits énergétiques"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/EACEI_T3_FR', 'byteSize': 16350, 'format': 'XLSX', 'id': 'EACEI_T3_FR', 'issued': '2025-10-24T17:58:47', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-10-24T17:58:47', 'title': 'Répartition de la consommation de combustibles par usage en milliers de tonnes-équivalent-pétrole (kTEP)'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/EACEI_T4_FR', 'byteSize': 14910, 'format': 'XLSX', 'id': 'EACEI_T4_FR', 'issued': '2025-10-24T17:58:51', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-10-24T17:58:51', 'title': "Autoproduction, achats et consommation d'électricité par usage en GWh"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EACEI/EACEI_T5_FR', 'byteSize': 13777, 'format': 'XLSX', 'id': 'EACEI_T5_FR', 'issued': '2025-10-24T17:58:50', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-10-24T17:58:50', 'title': 'Contrats d’électricité et de gaz'}]
# DS_EC_DECES
# [{'content': 'Nombre de décès quotidien, mensuel et annuel au niveau départemental, régional et national.', 'lang': 'fr'}, {'content': 'The number of daily, monthly, and annual deaths is available at the departmental, regional, and national levels. Some indicators are broken down by place of death or by sex and age. Depending on the indicator, data availability ranges from the last two to ten years. Other indicators, such as the number of deaths accumulated since January 1st, the average number of deaths per day over the past seven days, or per month, are also available.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_DECES/DS_EC_DECES_CSV_FR', 'byteSize': 6815151, 'format': 'CSV', 'id': 'DS_EC_DECES_CSV_FR', 'issued': '2026-01-09T11:29:16', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-01-27T13:39:53', 'packageFormat': 'application/zip', 'title': 'Décès quotidiens et mensuels'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_DECES/T1_DECES_JOUR_DEP_REG_FR', 'byteSize': 1567089, 'format': 'XLSX', 'id': 'T1_DECES_JOUR_DEP_REG_FR', 'issued': '2026-01-09T11:30:30', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-27T13:41:11', 'title': 'Nombre de décès par jour par département et par région de résidence du défunt'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_DECES/T1_DECES_JOUR_NAT_FR', 'byteSize': 17734, 'format': 'XLSX', 'id': 'T1_DECES_JOUR_NAT_FR', 'issued': '2026-01-09T11:30:31', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-27T13:41:11', 'title': 'Nombre de décès par jour au niveau national'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_DECES/T2_DECES_AN_DEP_REG_FR', 'byteSize': 20547, 'format': 'XLSX', 'id': 'T2_DECES_AN_DEP_REG_FR', 'issued': '2026-01-09T11:29:56', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-27T13:40:26', 'title': 'Nombre de décès annuels par département et par région de résidence du défunt'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_DECES/T3_DECES_JOUR_SEX_AGE_NAT_FR', 'byteSize': 82073, 'format': 'XLSX', 'id': 'T3_DECES_JOUR_SEX_AGE_NAT_FR', 'issued': '2026-01-09T11:29:56', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-27T13:40:24', 'title': "Nombre de décès quotidiens selon le sexe et l'âge, au niveau national"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_DECES/T4_DECES_JOUR_LIEU_NAT_FR', 'byteSize': 34664, 'format': 'XLSX', 'id': 'T4_DECES_JOUR_LIEU_NAT_FR', 'issued': '2026-01-09T11:30:31', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-27T13:41:12', 'title': 'Nombre de décès quotidiens selon le lieu de décès, au niveau national'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_DECES/T5_DECES_MOIS_LIEU_DEP_REG_FR', 'byteSize': 123603, 'format': 'XLSX', 'id': 'T5_DECES_MOIS_LIEU_DEP_REG_FR', 'issued': '2026-01-09T11:30:13', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-27T13:40:48', 'title': 'Nombre de décès par mois selon le lieu de décès, par département et par région de résidence du défunt'}]
# DS_EC_NAIS
# [{'content': 'Nombre de naissances mensuel et annuel au niveau départemental, régional et national.', 'lang': 'fr'}, {'content': 'Monthly and annual number of births at the departmental, regional, and national levels.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_NAIS/DS_EC_NAIS_CSV_FR', 'byteSize': 76199, 'format': 'CSV', 'id': 'DS_EC_NAIS_CSV_FR', 'issued': '2026-01-08T11:40:19', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-02-12T11:20:34.302900461', 'packageFormat': 'application/zip', 'title': 'Naissances mensuelles'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_EC_NAIS/NAIS_AN_DEP_REG_FR', 'byteSize': 20429, 'format': 'XLSX', 'id': 'NAIS_AN_DEP_REG_FR', 'issued': '2026-01-08T11:40:55', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-12T11:21:44.827614063', 'title': 'Nombre de naissances annuelles au niveau départemental et régional'}]
# DS_ELECTORAL
# [{'content': "Données sur les électeurs et les procurations au niveau départemental, régional et France entière y compris les collectivités d'outre mer hors Nouvelle-Calédonie en fonction de l'indicateur. ", 'lang': 'fr'}, {'content': 'Voter and proxy data at the departmental, regional, and national levels, including overseas territories except New Caledonia, based on the indicator.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ELECTORAL/DS_ELECTORAL_CSV_FR', 'byteSize': 1348089, 'format': 'CSV', 'id': 'DS_ELECTORAL_CSV_FR', 'issued': '2024-11-27T17:13:03', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2024-11-27T17:13:03', 'packageFormat': 'application/zip', 'title': 'Caractéristiques du corps électoral'}]
# DS_ENQPAT_DET
# [{'content': "Données nationales sur le patrimoine et l'endettement des ménages.", 'lang': 'fr'}, {'content': 'National data on household wealth and debt.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/hvp_distrib_patimmo_FR', 'byteSize': 6293, 'format': 'XLSX', 'id': 'hvp_distrib_patimmo_FR', 'issued': '2026-02-04T14:33:11', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-04T14:33:11', 'title': 'Distribution du patrimoine immobilier'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/hvp_mtendett_composante_det_FR', 'byteSize': 15816, 'format': 'XLSX', 'id': 'hvp_mtendett_composante_det_FR', 'issued': '2026-02-04T14:33:11', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-04T14:33:11', 'title': "Montant d'endettement moyen et décomposition détaillée"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/hvp_mtmoymed_patbrut_patnet_FR', 'byteSize': 12557, 'format': 'XLSX', 'id': 'hvp_mtmoymed_patbrut_patnet_FR', 'issued': '2026-02-04T14:33:12', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-04T14:33:12', 'title': 'Montants moyen et médian de patrimoine brut et net'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/hvp_mtpatbrut_composante_FR', 'byteSize': 13401, 'format': 'XLSX', 'id': 'hvp_mtpatbrut_composante_FR', 'issued': '2026-02-04T14:33:12', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-04T14:33:12', 'title': 'Montant de patrimoine brut moyen, décomposition par grandes composantes (y compris endettement)'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/hvp_mtpatbrut_composante_det_FR', 'byteSize': 16053, 'format': 'XLSX', 'id': 'hvp_mtpatbrut_composante_det_FR', 'issued': '2026-02-04T14:33:13', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-04T14:33:13', 'title': 'Montant de patrimoine brut moyen et décomposition détaillée'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/hvp_partmenag_endett_motif_FR', 'byteSize': 15833, 'format': 'XLSX', 'id': 'hvp_partmenag_endett_motif_FR', 'issued': '2026-02-04T14:33:13', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-04T14:33:13', 'title': 'Proportion de ménages endettés par motif'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/hvp_series_longues_FR', 'byteSize': 14595, 'format': 'XLSX', 'id': 'hvp_series_longues_FR', 'issued': '2026-02-04T14:33:14', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-04T14:33:14', 'title': 'Séries longues  '}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/hvp_txdetention_FR', 'byteSize': 17517, 'format': 'XLSX', 'id': 'hvp_txdetention_FR', 'issued': '2026-02-04T14:33:13', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-02-04T14:33:13', 'title': "Taux de détention par grand type d'actifs et de passifs"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_DET/DS_ENQPAT_DET_CSV_FR', 'byteSize': 33994, 'format': 'CSV', 'id': 'DS_ENQPAT_DET_CSV_FR', 'issued': '2026-02-04T14:32:54', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-02-04T14:32:54', 'packageFormat': 'application/zip', 'title': 'Détention et montants du patrimoine des ménages'}]
# DS_ENQPAT_TRANSM
# [{'content': 'Données nationales sur les transmissions intergénérationnelles reçues ou versées tout au long de la vie des individus : héritages, donations et aides financières.', 'lang': 'fr'}, {'content': "National data on intergenerational transfers received or given throughout individuals' lives: inheritances, donations, and financial aid.", 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_TRANSM/DS_ENQPAT_TRANSM_CSV_FR', 'byteSize': 8682, 'format': 'CSV', 'id': 'DS_ENQPAT_TRANSM_CSV_FR', 'issued': '2024-11-13T15:37:30', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-05-06T14:19:59', 'packageFormat': 'application/zip', 'title': 'Transmissions intergénérationnelles'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_TRANSM/hvp_aid_apport_enfhod_FR', 'byteSize': 19669, 'format': 'XLSX', 'id': 'hvp_aid_apport_enfhod_FR', 'issued': '2024-11-13T15:39:22', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-05-06T14:22:40', 'title': 'Aides apportées aux enfants hors domicile'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_TRANSM/hvp_aid_apport_par_FR', 'byteSize': 10639, 'format': 'XLSX', 'id': 'hvp_aid_apport_par_FR', 'issued': '2024-11-13T15:39:19', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-05-06T14:22:40', 'title': 'Aides apportées aux parents'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_TRANSM/hvp_cadrage_herit_donat_FR', 'byteSize': 9585, 'format': 'XLSX', 'id': 'hvp_cadrage_herit_donat_FR', 'issued': '2024-11-13T15:39:16', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-05-06T14:22:41', 'title': 'Données de cadrage sur les héritages et les donations'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_TRANSM/hvp_caract_herit_donat_FR', 'byteSize': 12513, 'format': 'XLSX', 'id': 'hvp_caract_herit_donat_FR', 'issued': '2024-11-13T15:39:12', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-05-06T14:22:42', 'title': 'Caractéristiques des ménages héritiers, donataires ou donateurs'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_TRANSM/hvp_donat_rec_FR', 'byteSize': 10563, 'format': 'XLSX', 'id': 'hvp_donat_rec_FR', 'issued': '2024-11-13T15:39:08', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-05-06T14:22:42', 'title': 'Donations reçues'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_TRANSM/hvp_donat_vers_enfhod_FR', 'byteSize': 12450, 'format': 'XLSX', 'id': 'hvp_donat_vers_enfhod_FR', 'issued': '2024-11-13T15:39:05', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-05-06T14:22:43', 'title': 'Donations versées aux enfants hors domicile'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_ENQPAT_TRANSM/hvp_herit_FR', 'byteSize': 10578, 'format': 'XLSX', 'id': 'hvp_herit_FR', 'issued': '2024-11-13T15:38:23', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-05-06T14:22:43', 'title': 'Héritages'}]
# DS_ERFS_CHAMP_CONST_SL
# [{'content': 'Données annuelles sur la pauvreté et le niveau de vie à champ constant depuis 1970.', 'lang': 'fr'}, {'content': 'Annual data on poverty and standard of living with a constant scope from 1970.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ERFS_CHAMP_CONST_SL/DS_ERFS_CHAMP_CONST_SL_2023_CSV_FR', 'byteSize': 2997, 'format': 'CSV', 'id': 'DS_ERFS_CHAMP_CONST_SL_2023_CSV_FR', 'issued': '2026-02-17T12:08:36.126064685', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-02-17T12:08:36.126064685', 'packageFormat': 'application/zip', 'title': 'Indicateurs de pauvreté et de niveau de vie (séries longues à champ constant)'}]
# DS_ERFS_INDIVIDU
# [{'content': 'Données annuelles sur la pauvreté et le niveau de vie pour le dernier millésime disponible.', 'lang': 'fr'}, {'content': 'Annual data on poverty and living standards for the latest available vintage.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ERFS_INDIVIDU/DS_ERFS_INDIVIDU_2023_CSV_FR', 'byteSize': 5870, 'format': 'CSV', 'id': 'DS_ERFS_INDIVIDU_2023_CSV_FR', 'issued': '2026-02-17T12:08:43.147178058', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-02-17T12:08:43.147178058', 'packageFormat': 'application/zip', 'title': 'Indicateurs de pauvreté et de niveau de vie (au niveau des individus pour le dernier millésime disponible)'}]
# DS_ERFS_INDIVIDU_SL
# [{'content': 'Données annuelles sur la pauvreté et le niveau de vie au niveau des individus.', 'lang': 'fr'}, {'content': 'Annual data on poverty and standard of living at the individual level.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ERFS_INDIVIDU_SL/DS_ERFS_INDIVIDU_SL_2023_CSV_FR', 'byteSize': 28999, 'format': 'CSV', 'id': 'DS_ERFS_INDIVIDU_SL_2023_CSV_FR', 'issued': '2026-02-17T12:08:31.874056569', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-02-17T12:08:31.874056569', 'packageFormat': 'application/zip', 'title': 'Indicateurs de niveau de vie et de pauvreté (pour les individus en série longue)'}]
# DS_ERFS_MENAGE
# [{'content': 'Données annuelles sur les revenus disponibles des ménages pour le dernier millésime disponible.', 'lang': 'fr'}, {'content': 'Annual data on household disposable income for the latest available vintage.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ERFS_MENAGE/DS_ERFS_MENAGE_2023_CSV_FR', 'byteSize': 4380, 'format': 'CSV', 'id': 'DS_ERFS_MENAGE_2023_CSV_FR', 'issued': '2026-02-17T12:08:59.561033398', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-02-17T12:08:59.561033398', 'packageFormat': 'application/zip', 'title': 'Indicateurs de revenu disponible (au niveau des ménages pour le dernier millésime disponible)'}]
# DS_ERFS_MENAGE_SL
# [{'content': 'Données annuelles sur le revenu disponible et la pauvreté au niveau des ménages.', 'lang': 'fr'}, {'content': 'Annual data on disposable income and poverty at the household level.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ERFS_MENAGE_SL/DS_ERFS_MENAGE_SL_2023_CSV_FR', 'byteSize': 11325, 'format': 'CSV', 'id': 'DS_ERFS_MENAGE_SL_2023_CSV_FR', 'issued': '2026-02-17T12:08:39.800945968', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-02-17T12:08:39.800945968', 'packageFormat': 'application/zip', 'title': 'Indicateurs de revenu disponible et de pauvreté (pour les ménages en série longue)'}]
# DS_ESTIMATION_POPULATION
# [{'content': 'Séries chronologiques et autres indicateurs sur la population au niveau départemental, régional et national', 'lang': 'fr'}, {'content': 'Time series and other population indicators at the departmental, regional, and national levels', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_ESTIMATION_POPULATION/DS_ESTIMATION_POPULATION_CSV_FR', 'byteSize': 3461686, 'format': 'CSV', 'id': 'DS_ESTIMATION_POPULATION_CSV_FR', 'issued': '2026-01-21T09:32:18', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-01-21T09:32:18', 'packageFormat': 'application/zip', 'title': 'Estimations localisées de population - séries longues'}]
# DS_ETAT_CIVIL_DECES_COMMUNES
# ...
# DS_SRCV_CONFIANCE
# [{'content': 'Données annuelles sur le niveau de confiance envers les personnes inconnues.', 'lang': 'fr'}, {'content': 'Annual data on the level of trust in strangers', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_CONFIANCE/DS_SRCV_CONFIANCE_2024_CSV_FR', 'byteSize': 4860, 'format': 'CSV', 'id': 'DS_SRCV_CONFIANCE_2024_CSV_FR', 'issued': '2025-09-10T11:30:29', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-09-10T11:30:29', 'packageFormat': 'application/zip', 'title': 'Conditions de vie : confiance envers les autres'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_CONFIANCE/SRCV_CONFIANCE_T1_FM_FR', 'byteSize': 26639, 'format': 'XLSX', 'id': 'SRCV_CONFIANCE_T1_FM_FR', 'issued': '2025-09-10T11:09:54', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-10T11:09:54', 'title': 'Confiance France métropolitaine de 2020 à 2024'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_CONFIANCE/SRCV_CONFIANCE_T2_F_FR', 'byteSize': 23596, 'format': 'XLSX', 'id': 'SRCV_CONFIANCE_T2_F_FR', 'issued': '2025-09-10T11:09:58', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-10T11:09:58', 'title': 'Confiance France hors Mayotte de 2022 à 2024'}]
# DS_SRCV_PMS
# [{'content': 'Données regroupant des indicateurs annuels sur la privation matérielle et sociale pour la France hors Mayotte.', 'lang': 'fr'}, {'content': 'Annual indicators on material and social deprivation in France (excluding Mayotte).', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_PMS/SRCV_PMS_T1_FM_PLUS_16_ANS_FR', 'byteSize': 43060, 'format': 'XLSX', 'id': 'SRCV_PMS_T1_FM_PLUS_16_ANS_FR', 'issued': '2025-09-10T10:14:22', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-10T10:14:22', 'title': 'Privation matérielle et sociale pour les 16 ans ou plus, pour la France métropolitaine de 2020 à 2024'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_PMS/SRCV_PMS_T2_FM_POP_FR', 'byteSize': 23901, 'format': 'XLSX', 'id': 'SRCV_PMS_T2_FM_POP_FR', 'issued': '2025-09-10T10:14:15', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-10T10:14:15', 'title': 'Privation matérielle et sociale pour la France métropolitaine de 2020 à 2024'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_PMS/SRCV_PMS_T3_F_PLUS_16_ANS_FR', 'byteSize': 33710, 'format': 'XLSX', 'id': 'SRCV_PMS_T3_F_PLUS_16_ANS_FR', 'issued': '2025-09-10T10:14:11', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-10T10:14:11', 'title': 'Privation matérielle et sociale pour les 16 ans ou plus, pour la France hors Mayotte de 2022 à 2024'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_PMS/SRCV_PMS_T4_F_POP_FR', 'byteSize': 19425, 'format': 'XLSX', 'id': 'SRCV_PMS_T4_F_POP_FR', 'issued': '2025-09-10T10:14:07', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-10T10:14:07', 'title': 'Privation matérielle et sociale pour la France hors Mayotte de 2022 à 2024'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_PMS/DS_SRCV_PMS_2024_CSV_FR', 'byteSize': 48692, 'format': 'CSV', 'id': 'DS_SRCV_PMS_2024_CSV_FR', 'issued': '2025-09-10T10:13:55', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-09-10T10:13:55', 'packageFormat': 'application/zip', 'title': 'Privations matérielles et sociales'}]
# DS_SRCV_SATISFACTION
# [{'content': 'Données annuelles sur la satisfaction subjective des personnes.', 'lang': 'fr'}, {'content': 'Annual data on individuals’ subjective satisfaction.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_SATISFACTION/DS_SRCV_SATISFACTION_2024_CSV_FR', 'byteSize': 53331, 'format': 'CSV', 'id': 'DS_SRCV_SATISFACTION_2024_CSV_FR', 'issued': '2025-09-10T11:08:26', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-09-10T11:08:26', 'packageFormat': 'application/zip', 'title': 'Conditions de vie : niveau de satisfaction'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_SATISFACTION/SRCV_SATISFACTION_T1_FM_FR', 'byteSize': 65072, 'format': 'XLSX', 'id': 'SRCV_SATISFACTION_T1_FM_FR', 'issued': '2025-09-10T11:12:03', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-10T11:12:03', 'title': 'Satisfaction France métropolitaine de 2010 à 2024'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_SRCV_SATISFACTION/SRCV_SATISFACTION_T2_F_FR', 'byteSize': 31058, 'format': 'XLSX', 'id': 'SRCV_SATISFACTION_T2_F_FR', 'issued': '2025-09-10T11:12:07', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-09-10T11:12:07', 'title': 'Satisfaction France hors Mayotte de 2022 à 2024'}]
# DS_SUIVI_DDE_TOUR
# [{'content': 'Données annuelles sur le suivi de la demande touristique au niveau national.', 'lang': 'fr'}, {'content': 'Annual, quarterly, and monthly tourism data on the attendance of tourist accommodations at the departmental, regional, and national levels.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_SUIVI_DDE_TOUR/DS_SUIVI_DDE_TOUR_CSV_FR', 'byteSize': 3328, 'format': 'CSV', 'id': 'DS_SUIVI_DDE_TOUR_CSV_FR', 'issued': '2025-10-03T12:46:09', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-10-03T12:46:09', 'packageFormat': 'application/zip', 'title': 'Suivi de la demande touristique'}]
# DS_TICE
# [{'content': 'Données pour 2024 sur les nouvelles technologies et le commerce électronique dans les entreprises. ', 'lang': 'fr'}, {'content': 'Data for 2024 on new technologies and e-commerce in enterprises.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_TICE/TICE_CCN_FR', 'byteSize': 6874, 'format': 'XLSX', 'id': 'TICE_CCN_FR', 'issued': '2025-01-15T10:02:31', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-01-15T10:02:31', 'title': 'Chiffres Clés - Commerce électronique'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICE/TICE_table1_FR', 'byteSize': 16113, 'format': 'XLSX', 'id': 'TICE_table1_FR', 'issued': '2025-01-15T11:07:57', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-01-15T11:07:57', 'title': 'Accès à Internet et usages'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICE/TICE_table2_FR', 'byteSize': 20036, 'format': 'XLSX', 'id': 'TICE_table2_FR', 'issued': '2025-01-15T11:07:37', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-01-15T11:07:37', 'title': 'Commerce électronique'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICE/TICE_table3_FR', 'byteSize': 14327, 'format': 'XLSX', 'id': 'TICE_table3_FR', 'issued': '2025-01-15T11:07:39', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-01-15T11:07:39', 'title': 'Spécialistes en TIC et compétences'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICE/TICE_table4_FR', 'byteSize': 19085, 'format': 'XLSX', 'id': 'TICE_table4_FR', 'issued': '2025-01-15T11:07:41', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-01-15T11:07:41', 'title': 'Sécurité des systèmes d’information'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICE/TICE_table5_FR', 'byteSize': 14710, 'format': 'XLSX', 'id': 'TICE_table5_FR', 'issued': '2025-01-15T11:07:43', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-01-15T11:07:43', 'title': 'Intelligence artificielle'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICE/TICE_table6_FR', 'byteSize': 9268, 'format': 'XLSX', 'id': 'TICE_table6_FR', 'issued': '2025-01-15T11:07:45', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-01-15T11:07:45', 'title': 'Technologies immersives'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICE/DS_TICE_CSV_FR', 'byteSize': 63944, 'format': 'CSV', 'id': 'DS_TICE_CSV_FR', 'issued': '2025-01-14T17:34:38', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-01-14T17:34:38', 'packageFormat': 'application/zip', 'title': 'Les TIC et le commerce électronique dans les entreprises'}]
# DS_TICM_EQUIPEMENT
# [{'content': 'Données sur l’équipement des ménages en internet au niveau national', 'lang': 'fr'}, {'content': 'Data on household internet access at the national level', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_TICM_EQUIPEMENT/DS_TICM_EQUIPEMENT_CSV_FR', 'byteSize': 30981, 'format': 'CSV', 'id': 'DS_TICM_EQUIPEMENT_CSV_FR', 'issued': '2025-12-02T14:07:56', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-12-02T14:07:56', 'packageFormat': 'application/zip', 'title': 'Équipement des ménages en internet '}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICM_EQUIPEMENT/TICM_TE1_FR', 'byteSize': 17344, 'format': 'XLSX', 'id': 'TICM_TE1_FR', 'issued': '2025-12-02T14:14:13', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-12-02T14:14:13', 'title': "Taux d'équipement en internet des ménages selon l'âge et le sexe"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICM_EQUIPEMENT/TICM_TE2_FR', 'byteSize': 21028, 'format': 'XLSX', 'id': 'TICM_TE2_FR', 'issued': '2025-12-02T14:14:13', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-12-02T14:14:13', 'title': "Taux d'équipement en internet des ménages selon l'âge et le diplôme"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TICM_EQUIPEMENT/TICM_TE3_FR', 'byteSize': 8459, 'format': 'XLSX', 'id': 'TICM_TE3_FR', 'issued': '2025-12-02T14:14:14', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-12-02T14:14:14', 'title': "Taux d'équipement en internet des ménages selon la PCS"}]
# DS_TICM_PRATIQUES
# [{'content': 'Données sur les pratiques en ligne des personnes au niveau national.', 'lang': 'fr'}, {'content': 'Data on the online practices of individuals at the national level.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_TICM_PRATIQUES/DS_TICM_PRATIQUES_CSV_FR', 'byteSize': 63335, 'format': 'CSV', 'id': 'DS_TICM_PRATIQUES_CSV_FR', 'issued': '2025-12-02T14:11:39', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2025-12-02T14:11:39', 'packageFormat': 'application/zip', 'title': 'Pratiques en ligne des personnes '}]
# DS_TOUR_CAP
# [{'content': "Données annuelles sur le tourisme portant sur les capacités d'accueil des touristes au niveau communal et supracommunal pour la France hors Mayotte.", 'lang': 'fr'}, {'content': 'Annual tourism data on the accommodation capacity for tourists at the municipal and supramunicipal levels for France excluding Mayotte.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_TOUR_CAP/DS_TOUR_CAP_2026_CSV_FR', 'byteSize': 10948256, 'format': 'CSV', 'id': 'DS_TOUR_CAP_2026_CSV_FR', 'issued': '2026-01-29T08:34:39', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-01-29T08:34:39', 'packageFormat': 'application/zip', 'title': "Capacités d'hébergements touristiques"}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TOUR_CAP/TOUR_CAP_AHCT_FR', 'byteSize': 1690448, 'format': 'XLSX', 'id': 'TOUR_CAP_AHCT_FR', 'issued': '2026-01-29T08:39:59', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-29T08:39:59', 'title': 'Capacité des communes en autres hébergements collectifs de tourisme'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TOUR_CAP/TOUR_CAP_AHCT_EN', 'byteSize': 1690366, 'format': 'XLSX', 'id': 'TOUR_CAP_AHCT_EN', 'issued': '2025-07-07T14:58:04', 'language': 'EN', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-07T14:58:04', 'title': 'Tourism accommodation capacity of municipalities in other collective lodging options'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TOUR_CAP/TOUR_CAP_CAMPINGS_FR', 'byteSize': 1855999, 'format': 'XLSX', 'id': 'TOUR_CAP_CAMPINGS_FR', 'issued': '2026-01-29T08:41:06', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-29T08:41:06', 'title': 'Capacité des communes en campings'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TOUR_CAP/TOUR_CAP_CAMPINGS_EN', 'byteSize': 1856158, 'format': 'XLSX', 'id': 'TOUR_CAP_CAMPINGS_EN', 'issued': '2025-07-07T15:00:07', 'language': 'EN', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-07T15:00:07', 'title': 'Camping capacity of municipalities'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TOUR_CAP/TOUR_CAP_HOTELS_FR', 'byteSize': 1874798, 'format': 'XLSX', 'id': 'TOUR_CAP_HOTELS_FR', 'issued': '2026-01-29T08:40:33', 'language': 'FR', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2026-01-29T08:40:33', 'title': 'Capacité des communes en hôtels'}, {'accessURL': 'https://api.insee.fr/melodi/file/DS_TOUR_CAP/TOUR_CAP_HOTELS_EN', 'byteSize': 1876762, 'format': 'XLSX', 'id': 'TOUR_CAP_HOTELS_EN', 'issued': '2025-07-07T14:59:06', 'language': 'EN', 'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'modified': '2025-07-07T14:59:06', 'title': 'Hotel capacity of municipalities'}]
# DS_TOUR_FREQ
# [{'content': 'Données annuelles, trimestrielles et mensuelles sur le tourisme portant sur la fréquentation des hébergements touristiques au niveau départemental, régional et national.', 'lang': 'fr'}, {'content': 'Annual, quarterly, and monthly tourism data on the attendance of tourist accommodations at the departmental, regional, and national levels.', 'lang': 'en'}]
# [{'accessURL': 'https://api.insee.fr/melodi/file/DS_TOUR_FREQ/DS_TOUR_FREQ_CSV_FR', 'byteSize': 1514324, 'format': 'CSV', 'id': 'DS_TOUR_FREQ_CSV_FR', 'issued': '2024-10-21T09:25:11', 'language': 'FR', 'mediaType': 'text/csv', 'modified': '2026-01-14T16:23:29', 'packageFormat': 'application/zip', 'title': 'Fréquentation des hébergements touristiques '}]

# %% [markdown]
# ## Files:
#
# ### Historical population:
#
# https://api.insee.fr/melodi/file/DS_POPULATIONS_HISTORIQUES/DS_POPULATIONS_HISTORIQUES_CSV_FR

# %%
print(data)
# Out:
# [{'abstract': [{'content': "Données annuelles de Produit Intérieur Brut (PIB) et grands agrégats économiques associés au PIB: revenu national brut (RNB), capacité ou besoin de financement de la Nation, grandes composantes de l'équilibre de l'offre et de la demande, ventilation des facteurs de production.", 'lang': 'fr'}, {'content': "Annual data on Gross Domestic Product (GDP) and the main economic aggregates associated with GDP: gross national income (GNI), the nation's capacity or need for financing, the main components of the balance between supply and demand, and the breakdown of factors of production.", 'lang': 'en'}], 'accessRights': [{'content': 'Libre', 'lang': 'fr'}, {'lang': 'en'}], 'accrualPeriodicity': {'label': [{'content': 'Annuel', 'lang': 'fr'}, {'content': 'Annual', 'lang': 'en'}]}, 'confidentialityStatus': [{'content': 'Libre', 'lang': 'fr'}, {'lang': 'en'}], 'creator': 'Insee', 'description': [{'content': "Le produit intérieur brut (PIB) est le principal agrégat mesurant l'activité économique. Il correspond à la somme des valeurs ajoutées brutes nouvellement créées par les unités productrices résidentes une année donnée, évaluées au prix du marché. Il donne une mesure des richesses nouvelles créées chaque année par le système productif et permet des comparaisons internationales. Le produit intérieur brut est publié à prix courants et en volume aux prix de l'année précédente chaînés. Son évolution en volume (c'est-à-dire hors effet de prix) mesure la croissance économique.\n\nLes grands agrégats économiques associés au PIB sont le revenu national brut (RNB), la capacité ou le besoin de financement de la Nation, les grandes composantes de l'équilibre entre les éléments de l'offre (PIB, importations) et de la demande (consommation, investissement, exportations), la ventilation des facteurs de production (emploi, stock de capital) par secteurs institutionnels (entreprises, ménages, administrations publiques considérés comme producteurs de richesses) et la valeur ajoutée brute qu'ils génèrent.\n\nLes données annuelles des grands agrégats économiques associés au PIB suivent les concepts et méthodes des comptes nationaux en base 2020 (première publication fin mai 2024) et font partie des données à forte valeur désignées par Eurostat (HVD). ", 'lang': 'fr'}, {'content': "Gross domestic product (GDP) is the main aggregate measuring economic activity. It corresponds to the sum of gross value added newly created by resident producer units in a given year, valued at market prices. It provides a measure of the new wealth created each year by the productive system and enables international comparisons. Gross domestic product is published at current prices and in volume terms at the previous year's chain-linked prices. Its change in volume (i.e. excluding the price effect) measures economic growth.\n\nThe main economic aggregates associated with GDP are gross national income (GNI), the nation's net lending or borrowing, the main components of the balance between supply (GDP, imports) and demand (consumption, investment, exports), the breakdown of factors of production (employment, capital stock) by institutional sector (companies, households, general government considered as wealth producers) and the gross value added they generate.\n\nThe annual data for the major economic aggregates associated with GDP are part of the high-value data designated by Eurostat (HVD).", 'lang': 'en'}], 'identifier': 'DD_CNA_AGREGATS', 'issued': '2024-06-10T15:39:49.000570341', 'keyword': [{'label': [{'content': 'HVD', 'lang': 'fr'}, {'content': 'HVD', 'lang': 'en'}]}], 'landingPage': [[{'lang': 'fr', 'url': ''}, {'lang': 'en', 'url': ''}]], 'modified': '2025-08-29T13:38:58.779979955', 'numObservations': 231164, 'numSeries': 0, 'ordreComposants': ['ACCOUNTING_ENTRY', 'ACTIVITY', 'COUNTERPART_AREA', 'EXPENDITURE', 'INSTR_ASSET', 'PRODUCT', 'PRICES', 'REF_YEAR_PRICE', 'REF_SECTOR', 'STO', 'TRANSFORMATION', 'UNIT_MEASURE', 'TIME_PERIOD', 'OBS_VAL ...
